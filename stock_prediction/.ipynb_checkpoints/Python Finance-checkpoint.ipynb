# %% [markdown]
# # Python for Finance
# #### Using pandas to read and clean data

# %%
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style

# %%
start = dt.datetime(2010,1,1)
end = dt.datetime(2018,10,25)

df = web.DataReader('JD','yahoo', start, end)
print(df.tail(10))
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-10-12  24.540001  24.900000  23.740000  24.450001  24.450001  20258500
# 2018-10-15  24.110001  24.639999  23.799999  24.139999  24.139999  11138200
# 2018-10-16  24.500000  24.700001  24.080000  24.629999  24.629999  11689500
# 2018-10-17  24.520000  24.610001  23.459999  23.680000  23.680000  15378700
# 2018-10-18  23.500000  24.132000  23.219999  23.330000  23.330000  15582300
# 2018-10-19  23.940001  23.950001  22.950001  23.010000  23.010000  12970000
# 2018-10-22  23.860001  24.110001  23.299999  23.540001  23.540001  13939900
# 2018-10-23  22.610001  23.590000  22.330000  23.230000  23.230000  17949600
# 2018-10-24  23.180000  23.200001  21.690001  21.760000  21.760000  22822200
# 2018-10-25  22.049999  22.590000  21.910000  22.559999  22.559999  13330200

# %%
df.to_csv('JD.csv')
df = pd.read_csv('JD.csv')
print(df.head(10))
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2014-05-22  21.750000  22.799999  20.240000  20.900000  20.900000  84449700
# 1  2014-05-23  21.250000  21.250000  19.940001  20.100000  20.100000  20890300
# 2  2014-05-27  20.280001  22.980000  20.250000  22.969999  22.969999  15338100
# 3  2014-05-28  22.980000  25.299999  22.799999  24.780001  24.780001  16783000
# 4  2014-05-29  25.040001  25.690001  24.240000  25.400000  25.400000   8525900
# 5  2014-05-30  25.270000  25.559999  23.790001  25.000000  25.000000   6302800
# 6  2014-06-02  25.400000  25.440001  24.070000  24.600000  24.600000   3808800
# 7  2014-06-03  24.170000  25.250000  24.030001  25.100000  25.100000   3388500
# 8  2014-06-04  24.990000  25.280001  24.440001  24.540001  24.540001   2990800
# 9  2014-06-05  24.799999  26.750000  24.600000  25.780001  25.780001   7933500

# %%
df = pd.read_csv('JD.csv', parse_dates=True, index_col=0)
#del df['Unnamed: 0']
print(df.head(10))
#Date is a datetime index
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-05-22  21.750000  22.799999  20.240000  20.900000  20.900000  84449700
# 2014-05-23  21.250000  21.250000  19.940001  20.100000  20.100000  20890300
# 2014-05-27  20.280001  22.980000  20.250000  22.969999  22.969999  15338100
# 2014-05-28  22.980000  25.299999  22.799999  24.780001  24.780001  16783000
# 2014-05-29  25.040001  25.690001  24.240000  25.400000  25.400000   8525900
# 2014-05-30  25.270000  25.559999  23.790001  25.000000  25.000000   6302800
# 2014-06-02  25.400000  25.440001  24.070000  24.600000  24.600000   3808800
# 2014-06-03  24.170000  25.250000  24.030001  25.100000  25.100000   3388500
# 2014-06-04  24.990000  25.280001  24.440001  24.540001  24.540001   2990800
# 2014-06-05  24.799999  26.750000  24.600000  25.780001  25.780001   7933500

# %% [markdown]
# #### Using matplotlib to plot graphs

# %%
style.use('ggplot')
df.plot()
plt.show()

# %%
price_df = df.drop('Volume', axis=1)
price_df.plot()
plt.show()

# %%
price_df['Adj Close'].plot()
plt.show()

# %%
price_df['100MA'] = price_df['Adj Close'].rolling(window=100).mean()
price_df['30MA'] = price_df['Adj Close'].rolling(window=30).mean()
#price_df.dropna(inplace=True)
price_df
# Out:
#                  Open       High        Low      Close  Adj Close    100MA  \
# Date
# 2014-05-22  21.750000  22.799999  20.240000  20.900000  20.900000      NaN
# 2014-05-23  21.250000  21.250000  19.940001  20.100000  20.100000      NaN
# 2014-05-27  20.280001  22.980000  20.250000  22.969999  22.969999      NaN
# 2014-05-28  22.980000  25.299999  22.799999  24.780001  24.780001      NaN
# 2014-05-29  25.040001  25.690001  24.240000  25.400000  25.400000      NaN
# 2014-05-30  25.270000  25.559999  23.790001  25.000000  25.000000      NaN
# 2014-06-02  25.400000  25.440001  24.070000  24.600000  24.600000      NaN
# 2014-06-03  24.170000  25.250000  24.030001  25.100000  25.100000      NaN
# 2014-06-04  24.990000  25.280001  24.440001  24.540001  24.540001      NaN
# 2014-06-05  24.799999  26.750000  24.600000  25.780001  25.780001      NaN
# 2014-06-06  26.500000  27.040001  26.309999  26.580000  26.580000      NaN
# 2014-06-09  27.000000  29.090000  26.580000  28.430000  28.430000      NaN
# 2014-06-10  28.820000  28.860001  27.700001  28.350000  28.350000      NaN
# 2014-06-11  28.100000  29.490000  28.100000  29.000000  29.000000      NaN
# 2014-06-12  29.590000  29.600000  26.340000  27.170000  27.170000      NaN
# 2014-06-13  27.680000  28.200001  27.129999  27.790001  27.790001      NaN
# 2014-06-16  27.219999  27.440001  26.379999  26.889999  26.889999      NaN
# 2014-06-17  27.219999  27.450001  26.629999  27.018999  27.018999      NaN
# 2014-06-18  27.440001  27.889999  26.030001  26.520000  26.520000      NaN
# 2014-06-19  27.000000  27.000000  25.799999  25.830000  25.830000      NaN
# 2014-06-20  25.750000  25.969999  24.920000  25.450001  25.450001      NaN
# 2014-06-23  25.110001  26.459999  25.100000  26.370001  26.370001      NaN
# 2014-06-24  26.510000  27.340000  26.510000  27.040001  27.040001      NaN
# 2014-06-25  27.250000  27.350000  26.450001  27.070000  27.070000      NaN
# 2014-06-26  27.139999  28.350000  26.809999  28.299999  28.299999      NaN
# 2014-06-27  28.360001  28.500000  27.709999  28.010000  28.010000      NaN
# 2014-06-30  28.170000  28.530001  27.680000  28.510000  28.510000      NaN
# 2014-07-01  29.000000  31.219999  28.860001  29.690001  29.690001      NaN
# 2014-07-02  30.400000  30.410000  28.500000  28.959999  28.959999      NaN
# 2014-07-03  29.280001  29.350000  27.530001  27.790001  27.790001      NaN
# ...               ...        ...        ...        ...        ...      ...
# 2018-09-14  27.910000  28.030001  27.040001  27.110001  27.110001  36.0618
# 2018-09-17  26.125000  26.184999  25.330000  25.730000  25.730000  35.9603
# 2018-09-18  25.900000  26.090000  25.270000  25.750000  25.750000  35.8528
# 2018-09-19  26.120001  27.110001  26.120001  26.920000  26.920000  35.7544
# 2018-09-20  27.200001  27.264999  26.650000  26.930000  26.930000  35.6586
# 2018-09-21  27.309999  27.350000  26.250000  26.490000  26.490000  35.5488
# 2018-09-24  25.059999  25.530001  24.379999  24.510000  24.510000  35.4231
# 2018-09-25  24.799999  24.840000  24.400000  24.540001  24.540001  35.2965
# 2018-09-26  24.719999  25.860001  24.660000  25.200001  25.200001  35.1718
# 2018-09-27  25.400000  25.889999  25.280001  25.430000  25.430000  35.0389
# 2018-09-28  25.299999  26.230000  25.299999  26.090000  26.090000  34.9304
# 2018-10-01  26.030001  26.260000  25.379999  25.490000  25.490000  34.8139
# 2018-10-02  25.100000  25.400000  24.540001  24.900000  24.900000  34.6944
# 2018-10-03  25.150000  25.440001  24.790001  25.139999  25.139999  34.5763
# 2018-10-04  24.780001  24.850000  24.062000  24.320000  24.320000  34.4478
# 2018-10-05  24.200001  24.250000  23.370001  23.620001  23.620001  34.3228
# 2018-10-08  23.020000  24.240000  22.650000  23.889999  23.889999  34.1974
# 2018-10-09  23.450001  24.200001  23.340000  23.780001  23.780001  34.0756
# 2018-10-10  23.450001  23.549999  22.700001  22.709999  22.709999  33.9456
# 2018-10-11  22.520000  23.660000  22.500000  23.480000  23.480000  33.8176
# 2018-10-12  24.540001  24.900000  23.740000  24.450001  24.450001  33.6985
# 2018-10-15  24.110001  24.639999  23.799999  24.139999  24.139999  33.5727
# 2018-10-16  24.500000  24.700001  24.080000  24.629999  24.629999  33.4520
# 2018-10-17  24.520000  24.610001  23.459999  23.680000  23.680000  33.3201
# 2018-10-18  23.500000  24.132000  23.219999  23.330000  23.330000  33.1881
# 2018-10-19  23.940001  23.950001  22.950001  23.010000  23.010000  33.0602
# 2018-10-22  23.860001  24.110001  23.299999  23.540001  23.540001  32.9438
# 2018-10-23  22.610001  23.590000  22.330000  23.230000  23.230000  32.8152
# 2018-10-24  23.180000  23.200001  21.690001  21.760000  21.760000  32.6512
# 2018-10-25  22.049999  22.590000  21.910000  22.559999  22.559999  32.4881
#
#                  30MA
# Date
# 2014-05-22        NaN
# 2014-05-23        NaN
# 2014-05-27        NaN
# 2014-05-28        NaN
# 2014-05-29        NaN
# 2014-05-30        NaN
# 2014-06-02        NaN
# 2014-06-03        NaN
# 2014-06-04        NaN
# 2014-06-05        NaN
# 2014-06-06        NaN
# 2014-06-09        NaN
# 2014-06-10        NaN
# 2014-06-11        NaN
# 2014-06-12        NaN
# 2014-06-13        NaN
# 2014-06-16        NaN
# 2014-06-17        NaN
# 2014-06-18        NaN
# 2014-06-19        NaN
# 2014-06-20        NaN
# 2014-06-23        NaN
# 2014-06-24        NaN
# 2014-06-25        NaN
# 2014-06-26        NaN
# 2014-06-27        NaN
# 2014-06-30        NaN
# 2014-07-01        NaN
# 2014-07-02        NaN
# 2014-07-03  26.331300
# ...               ...
# 2018-09-14  31.599000
# 2018-09-17  31.251000
# 2018-09-18  30.912667
# 2018-09-19  30.593333
# 2018-09-20  30.291000
# 2018-09-21  29.973333
# 2018-09-24  29.597333
# 2018-09-25  29.246333
# 2018-09-26  28.957333
# 2018-09-27  28.726333
# 2018-09-28  28.530333
# 2018-10-01  28.306000
# 2018-10-02  28.034667
# 2018-10-03  27.779333
# 2018-10-04  27.512000
# 2018-10-05  27.253000
# 2018-10-08  27.002667
# 2018-10-09  26.706333
# 2018-10-10  26.391333
# 2018-10-11  26.109000
# 2018-10-12  25.890667
# 2018-10-15  25.652000
# 2018-10-16  25.492000
# 2018-10-17  25.404667
# 2018-10-18  25.274000
# 2018-10-19  25.142667
# 2018-10-22  25.043000
# 2018-10-23  24.914333
# 2018-10-24  24.718667
# 2018-10-25  24.545333
#
# [1117 rows x 7 columns]

# %%
price_df[['Adj Close','100MA','30MA']].plot()
plt.show()

# %%
# putting up the shape of the plot
ax1 = plt.subplot2grid((6,1),(0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1),(5,0), rowspan=1, colspan=1, sharex=ax1)

# what content to plot on the two sub graphs(x, y)
ax1.plot(price_df.index, price_df['Adj Close'])
ax1.plot(price_df.index, price_df[['100MA','30MA']])
ax2.bar(df.index, df['Volume'])
plt.show()

# %% [markdown]
# #### Resampling the data and ploting candle graph with ohlc and moving averages

# %%
from matplotlib.finance import candlestick_ohlc
import matplotlib.dates as mdates

# resample price data into weekly data
# in situation like stock split, we can only use this way to get the accurate ohlc data.
df_ohlc = df['Adj Close'].resample('7D').ohlc()
df_30ma = price_df['30MA'].resample('7D').mean()
df_100ma = price_df['100MA'].resample('7D').mean()
df_volume = df['Volume'].resample('7D').sum()

print(df_ohlc.head())
print(df_volume.head())
print(df_30ma.tail())
print(df_100ma.tail())
# Out:
#                  open       high        low      close
# Date
# 2014-05-22  20.900000  24.780001  20.100000  24.780001
# 2014-05-29  25.400000  25.400000  24.540001  24.540001
# 2014-06-05  25.780001  29.000000  25.780001  29.000000
# 2014-06-12  27.170000  27.790001  26.520000  26.520000
# 2014-06-19  25.830000  27.070000  25.450001  27.070000
# Date
# 2014-05-22    137461100
# 2014-05-29     25016800
# 2014-06-05     35083600
# 2014-06-12     29411700
# 2014-06-19     24582500
# Freq: 7D, Name: Volume, dtype: int64
# Date
# 2018-09-27    28.275333
# 2018-10-04    26.973067
# 2018-10-11    25.709667
# 2018-10-18    25.018533
# 2018-10-25    24.545333
# Freq: 7D, Name: 30MA, dtype: float64
# Date
# 2018-09-27    34.81078
# 2018-10-04    34.19784
# 2018-10-11    33.57218
# 2018-10-18    32.93170
# 2018-10-25    32.48810
# Freq: 7D, Name: 100MA, dtype: float64

# %%
# need to map Dates to mdates in matplotlib

# move Date from index to column
df_ohlc.reset_index(inplace=True)
df_ohlc.head()
# Out:
#         Date       open       high        low      close
# 0 2014-05-22  20.900000  24.780001  20.100000  24.780001
# 1 2014-05-29  25.400000  25.400000  24.540001  24.540001
# 2 2014-06-05  25.780001  29.000000  25.780001  29.000000
# 3 2014-06-12  27.170000  27.790001  26.520000  26.520000
# 4 2014-06-19  25.830000  27.070000  25.450001  27.070000

# %%
# matplotlib will formulate mdates into years
df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)
df_ohlc.head()
# Out:
#        Date       open       high        low      close
# 0  735375.0  20.900000  24.780001  20.100000  24.780001
# 1  735382.0  25.400000  25.400000  24.540001  24.540001
# 2  735389.0  25.780001  29.000000  25.780001  29.000000
# 3  735396.0  27.170000  27.790001  26.520000  26.520000
# 4  735403.0  25.830000  27.070000  25.450001  27.070000

# %%
# %matplotlib notebook 
# putting up the shape of the plot
ax1 = plt.subplot2grid((6,1),(0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1),(5,0), rowspan=1, colspan=1, sharex=ax1)
# display beautiful date using mdates
ax1.xaxis_date()

# what content to plot on the two sub graphs(x, y)
candlestick_ohlc(ax1, df_ohlc.values, width=2, colorup='g')

ax1.plot(df_30ma.index.map(mdates.date2num), df_30ma, color='grey')
ax1.plot(df_100ma.index.map(mdates.date2num), df_100ma, color='purple')
ax2.fill_between(df_volume.index.map(mdates.date2num), df_volume.values, 0, color='grey')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### data scraping using bs4

# %%
from bs4 import BeautifulSoup
import pickle
import requests

tickers = []

# %% [markdown]
# * *getting all S&P 500 stock tickers using BeautifulSoup*

# %%
def save_sp500_tickers():
    resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    html = resp.text
    soup = BeautifulSoup(html, 'lxml')
    # print(soup.prettify())
    # find the first table tag with class wikitable sortable
    table = soup.find('table',{'class':'wikitable sortable'})
    global tickers
    # find the first td(table data) cell in a list of tr excluding the columns headings
    for line in table.findAll('tr')[1:]:
        ticker = line.find('td').text.replace('.','-')
        print(ticker, end=' ')
        tickers.append(ticker)
    # dump the entire list into a pickle file
    with open('sp500.pickle', 'wb') as file:
        pickle.dump(tickers, file)

save_sp500_tickers()
# Out:
# MMM ABT ABBV ABMD ACN ATVI ADBE AMD AAP AES AET AMG AFL A APD AKAM ALK ALB ARE ALXN ALGN ALLE AGN ADS LNT ALL GOOGL GOOG MO AMZN AEE AAL AEP AXP AIG AMT AWK AMP ABC AME AMGN APH APC ADI ANSS ANTM AON AOS APA AIV AAPL AMAT APTV ADM ARNC ANET AJG AIZ T ADSK ADP AZO AVB AVY BHGE BLL BAC BK BAX BBT BDX BRK-B BBY BIIB BLK HRB BA BKNG BWA BXP BSX BHF BMY AVGO BR BF-B CHRW CA COG CDNS CPB COF CAH KMX CCL CAT CBOE CBRE CBS CELG CNC CNP CTL CERN CF SCHW CHTR CVX CMG CB CHD CI XEC CINF CTAS CSCO C CFG CTXS CLX CME CMS KO CTSH CL CMCSA CMA CAG CXO COP ED STZ COO CPRT GLW COST COTY CCI CSX CMI CVS DHI DHR DRI DVA DE DAL XRAY DVN DLR DFS DISCA DISCK DISH DG DLTR D DOV DWDP DTE DRE DUK DXC ETFC EMN ETN EBAY ECL EIX EW EA EMR ETR EOG EQT EFX EQIX EQR ESS EL EVRG ES RE EXC EXPE EXPD ESRX EXR XOM FFIV FB FAST FRT FDX FIS FITB FE FISV FLT FLIR FLS FLR FMC FL F FTNT FTV FBHS BEN FCX GPS GRMN IT GD GE GIS GM GPC GILD GPN GS GT GWW HAL HBI HOG HRS HIG HAS HCA HCP HP HSIC HSY HES HPE HLT HFC HOLX HD HON HRL HST HPQ HUM HBAN HII IDXX INFO ITW ILMN IR INTC ICE IBM INCY IP IPG IFF INTU ISRG IVZ IPGP IQV IRM JEC JBHT JEF SJM JNJ JCI JPM JNPR KSU K KEY KMB KIM KMI KLAC KSS KHC KR LB LLL LH LRCX LEG LEN LLY LNC LIN LKQ LMT L LOW LYB MTB MAC M MRO MPC MAR MMC MLM MAS MA MAT MKC MCD MCK MDT MRK MET MTD MGM KORS MCHP MU MSFT MAA MHK TAP MDLZ MNST MCO MS MOS MSI MSCI MYL NDAQ NOV NKTR NTAP NFLX NWL NFX NEM NWSA NWS NEE NLSN NKE NI NBL JWN NSC NTRS NOC NCLH NRG NUE NVDA ORLY OXY OMC OKE ORCL PCAR PKG PH PAYX PYPL PNR PBCT PEP PKI PRGO PFE PCG PM PSX PNW PXD PNC RL PPG PPL PFG PG PGR PLD PRU PEG PSA PHM PVH QRVO PWR QCOM DGX RJF RTN O RHT REG REGN RF RSG RMD RHI ROK COL ROL ROP ROST RCL CRM SBAC SCG SLB STX SEE SRE SHW SPG SWKS SLG SNA SO LUV SPGI SWK SBUX STT SRCL SYK STI SIVB SYMC SYF SNPS SYY TROW TTWO TPR TGT TEL FTI TXN TXT TMO TIF TWTR TJX TMK TSS TSCO TDG TRV TRIP FOXA FOX TSN UDR ULTA USB UAA UA UNP UAL UNH UPS URI UTX UHS UNM VFC VLO VAR VTR VRSN VRSK VZ VRTX VIAB V VNO VMC WMT WBA DIS WM WAT WEC WCG WFC WELL WDC WU WRK WY WHR WMB WLTW WYNN XEL XRX XLNX XYL YUM ZBH ZION ZTS

# %%
import datetime as dt
import os
import pandas as pd
import pandas_datareader.data as web
import time
import sys

def get_data_from_yahoo(reload_sp500=False):
    if reload_sp500:
        save_sp500_tickers()
    else:
        with open('sp500.pickle', 'rb') as file:
            global tickers
            tickers = pickle.load(file)
            
    if not os.path.exists('stock_dfs'):
        os.makedirs('stock_dfs')
    
    start = dt.datetime(2000,1,1)
    end = dt.datetime(2018,10,31)
    
    for ticker in tickers:
        print('Crawling data for stock:', ticker)
        if not os.path.exists('stock_dfs/{}.csv'.format(ticker)):
            try:
                df = web.DataReader(ticker, 'yahoo', start, end)
                df.to_csv('stock_dfs/{}.csv'.format(ticker))
                print('Done')
            except:
                time.sleep(1)
                print('Pause to restart')
                try:
                    df = web.DataReader(ticker, 'yahoo', start, end)
                    df.to_csv('stock_dfs/{}.csv'.format(ticker))
                    print('Done')
                except:
                    time.sleep(5)
                    print('Pause longer to restart')
                    df = web.DataReader(ticker, 'yahoo', start, end)
                    df.to_csv('stock_dfs/{}.csv'.format(ticker))
                    print('Done')
        else:
            print('Already have {} data'.format(ticker))

get_data_from_yahoo()
# Out:
# Crawling data for stock: MMM
# Already have MMM data
# Crawling data for stock: ABT
# Already have ABT data
# Crawling data for stock: ABBV
# Already have ABBV data
# Crawling data for stock: ABMD
# Already have ABMD data
# Crawling data for stock: ACN
# Already have ACN data
# Crawling data for stock: ATVI
# Already have ATVI data
# Crawling data for stock: ADBE
# Already have ADBE data
# Crawling data for stock: AMD
# Already have AMD data
# Crawling data for stock: AAP
# Already have AAP data
# Crawling data for stock: AES
# Already have AES data
# Crawling data for stock: AET
# Already have AET data
# Crawling data for stock: AMG
# Already have AMG data
# Crawling data for stock: AFL
# Already have AFL data
# Crawling data for stock: A
# Already have A data
# Crawling data for stock: APD
# Already have APD data
# Crawling data for stock: AKAM
# Already have AKAM data
# Crawling data for stock: ALK
# Already have ALK data
# Crawling data for stock: ALB
# Already have ALB data
# Crawling data for stock: ARE
# Already have ARE data
# Crawling data for stock: ALXN
# Already have ALXN data
# Crawling data for stock: ALGN
# Already have ALGN data
# Crawling data for stock: ALLE
# Already have ALLE data
# Crawling data for stock: AGN
# Already have AGN data
# Crawling data for stock: ADS
# Already have ADS data
# Crawling data for stock: LNT
# Already have LNT data
# Crawling data for stock: ALL
# Already have ALL data
# Crawling data for stock: GOOGL
# Already have GOOGL data
# Crawling data for stock: GOOG
# Already have GOOG data
# Crawling data for stock: MO
# Already have MO data
# Crawling data for stock: AMZN
# Already have AMZN data
# Crawling data for stock: AEE
# Already have AEE data
# Crawling data for stock: AAL
# Already have AAL data
# Crawling data for stock: AEP
# Already have AEP data
# Crawling data for stock: AXP
# Already have AXP data
# Crawling data for stock: AIG
# Already have AIG data
# Crawling data for stock: AMT
# Already have AMT data
# Crawling data for stock: AWK
# Already have AWK data
# Crawling data for stock: AMP
# Already have AMP data
# Crawling data for stock: ABC
# Already have ABC data
# Crawling data for stock: AME
# Already have AME data
# Crawling data for stock: AMGN
# Already have AMGN data
# Crawling data for stock: APH
# Already have APH data
# Crawling data for stock: APC
# Already have APC data
# Crawling data for stock: ADI
# Already have ADI data
# Crawling data for stock: ANSS
# Already have ANSS data
# Crawling data for stock: ANTM
# Already have ANTM data
# Crawling data for stock: AON
# Already have AON data
# Crawling data for stock: AOS
# Already have AOS data
# Crawling data for stock: APA
# Already have APA data
# Crawling data for stock: AIV
# Already have AIV data
# Crawling data for stock: AAPL
# Already have AAPL data
# Crawling data for stock: AMAT
# Already have AMAT data
# Crawling data for stock: APTV
# Already have APTV data
# Crawling data for stock: ADM
# Already have ADM data
# Crawling data for stock: ARNC
# Already have ARNC data
# Crawling data for stock: ANET
# Already have ANET data
# Crawling data for stock: AJG
# Already have AJG data
# Crawling data for stock: AIZ
# Already have AIZ data
# Crawling data for stock: T
# Already have T data
# Crawling data for stock: ADSK
# Already have ADSK data
# Crawling data for stock: ADP
# Already have ADP data
# Crawling data for stock: AZO
# Already have AZO data
# Crawling data for stock: AVB
# Already have AVB data
# Crawling data for stock: AVY
# Already have AVY data
# Crawling data for stock: BHGE
# Already have BHGE data
# Crawling data for stock: BLL
# Already have BLL data
# Crawling data for stock: BAC
# Already have BAC data
# Crawling data for stock: BK
# Already have BK data
# Crawling data for stock: BAX
# Already have BAX data
# Crawling data for stock: BBT
# Already have BBT data
# Crawling data for stock: BDX
# Already have BDX data
# Crawling data for stock: BRK-B
# Already have BRK-B data
# Crawling data for stock: BBY
# Already have BBY data
# Crawling data for stock: BIIB
# Already have BIIB data
# Crawling data for stock: BLK
# Already have BLK data
# Crawling data for stock: HRB
# Already have HRB data
# Crawling data for stock: BA
# Already have BA data
# Crawling data for stock: BKNG
# Already have BKNG data
# Crawling data for stock: BWA
# Already have BWA data
# Crawling data for stock: BXP
# Already have BXP data
# Crawling data for stock: BSX
# Already have BSX data
# Crawling data for stock: BHF
# Already have BHF data
# Crawling data for stock: BMY
# Already have BMY data
# Crawling data for stock: AVGO
# Already have AVGO data
# Crawling data for stock: BR
# Already have BR data
# Crawling data for stock: BF-B
# Already have BF-B data
# Crawling data for stock: CHRW
# Already have CHRW data
# Crawling data for stock: CA
# Already have CA data
# Crawling data for stock: COG
# Already have COG data
# Crawling data for stock: CDNS
# Already have CDNS data
# Crawling data for stock: CPB
# Already have CPB data
# Crawling data for stock: COF
# Already have COF data
# Crawling data for stock: CAH
# Already have CAH data
# Crawling data for stock: KMX
# Already have KMX data
# Crawling data for stock: CCL
# Already have CCL data
# Crawling data for stock: CAT
# Already have CAT data
# Crawling data for stock: CBOE
# Already have CBOE data
# Crawling data for stock: CBRE
# Already have CBRE data
# Crawling data for stock: CBS
# Already have CBS data
# Crawling data for stock: CELG
# Already have CELG data
# Crawling data for stock: CNC
# Already have CNC data
# Crawling data for stock: CNP
# Already have CNP data
# Crawling data for stock: CTL
# Already have CTL data
# Crawling data for stock: CERN
# Already have CERN data
# Crawling data for stock: CF
# Already have CF data
# Crawling data for stock: SCHW
# Already have SCHW data
# Crawling data for stock: CHTR
# Already have CHTR data
# Crawling data for stock: CVX
# Already have CVX data
# Crawling data for stock: CMG
# Already have CMG data
# Crawling data for stock: CB
# Already have CB data
# Crawling data for stock: CHD
# Already have CHD data
# Crawling data for stock: CI
# Already have CI data
# Crawling data for stock: XEC
# Already have XEC data
# Crawling data for stock: CINF
# Already have CINF data
# Crawling data for stock: CTAS
# Already have CTAS data
# Crawling data for stock: CSCO
# Already have CSCO data
# Crawling data for stock: C
# Already have C data
# Crawling data for stock: CFG
# Already have CFG data
# Crawling data for stock: CTXS
# Already have CTXS data
# Crawling data for stock: CLX
# Already have CLX data
# Crawling data for stock: CME
# Already have CME data
# Crawling data for stock: CMS
# Already have CMS data
# Crawling data for stock: KO
# Already have KO data
# Crawling data for stock: CTSH
# Already have CTSH data
# Crawling data for stock: CL
# Already have CL data
# Crawling data for stock: CMCSA
# Already have CMCSA data
# Crawling data for stock: CMA
# Already have CMA data
# Crawling data for stock: CAG
# Already have CAG data
# Crawling data for stock: CXO
# Already have CXO data
# Crawling data for stock: COP
# Already have COP data
# Crawling data for stock: ED
# Already have ED data
# Crawling data for stock: STZ
# Already have STZ data
# Crawling data for stock: COO
# Already have COO data
# Crawling data for stock: CPRT
# Already have CPRT data
# Crawling data for stock: GLW
# Already have GLW data
# Crawling data for stock: COST
# Already have COST data
# Crawling data for stock: COTY
# Already have COTY data
# Crawling data for stock: CCI
# Already have CCI data
# Crawling data for stock: CSX
# Already have CSX data
# Crawling data for stock: CMI
# Already have CMI data
# Crawling data for stock: CVS
# Already have CVS data
# Crawling data for stock: DHI
# Already have DHI data
# Crawling data for stock: DHR
# Already have DHR data
# Crawling data for stock: DRI
# Already have DRI data
# Crawling data for stock: DVA
# Already have DVA data
# Crawling data for stock: DE
# Already have DE data
# Crawling data for stock: DAL
# Already have DAL data
# Crawling data for stock: XRAY
# Already have XRAY data
# Crawling data for stock: DVN
# Already have DVN data
# Crawling data for stock: DLR
# Already have DLR data
# Crawling data for stock: DFS
# Already have DFS data
# Crawling data for stock: DISCA
# Already have DISCA data
# Crawling data for stock: DISCK
# Already have DISCK data
# Crawling data for stock: DISH
# Already have DISH data
# Crawling data for stock: DG
# Already have DG data
# Crawling data for stock: DLTR
# Already have DLTR data
# Crawling data for stock: D
# Already have D data
# Crawling data for stock: DOV
# Already have DOV data
# Crawling data for stock: DWDP
# Already have DWDP data
# Crawling data for stock: DTE
# Already have DTE data
# Crawling data for stock: DRE
# Already have DRE data
# Crawling data for stock: DUK
# Already have DUK data
# Crawling data for stock: DXC
# Already have DXC data
# Crawling data for stock: ETFC
# Already have ETFC data
# Crawling data for stock: EMN
# Already have EMN data
# Crawling data for stock: ETN
# Already have ETN data
# Crawling data for stock: EBAY
# Already have EBAY data
# Crawling data for stock: ECL
# Already have ECL data
# Crawling data for stock: EIX
# Already have EIX data
# Crawling data for stock: EW
# Already have EW data
# Crawling data for stock: EA
# Already have EA data
# Crawling data for stock: EMR
# Already have EMR data
# Crawling data for stock: ETR
# Already have ETR data
# Crawling data for stock: EOG
# Already have EOG data
# Crawling data for stock: EQT
# Already have EQT data
# Crawling data for stock: EFX
# Already have EFX data
# Crawling data for stock: EQIX
# Already have EQIX data
# Crawling data for stock: EQR
# Already have EQR data
# Crawling data for stock: ESS
# Already have ESS data
# Crawling data for stock: EL
# Already have EL data
# Crawling data for stock: EVRG
# Already have EVRG data
# Crawling data for stock: ES
# Already have ES data
# Crawling data for stock: RE
# Already have RE data
# Crawling data for stock: EXC
# Already have EXC data
# Crawling data for stock: EXPE
# Already have EXPE data
# Crawling data for stock: EXPD
# Already have EXPD data
# Crawling data for stock: ESRX
# Already have ESRX data
# Crawling data for stock: EXR
# Already have EXR data
# Crawling data for stock: XOM
# Already have XOM data
# Crawling data for stock: FFIV
# Already have FFIV data
# Crawling data for stock: FB
# Already have FB data
# Crawling data for stock: FAST
# Already have FAST data
# Crawling data for stock: FRT
# Already have FRT data
# Crawling data for stock: FDX
# Already have FDX data
# Crawling data for stock: FIS
# Already have FIS data
# Crawling data for stock: FITB
# Already have FITB data
# Crawling data for stock: FE
# Already have FE data
# Crawling data for stock: FISV
# Already have FISV data
# Crawling data for stock: FLT
# Already have FLT data
# Crawling data for stock: FLIR
# Already have FLIR data
# Crawling data for stock: FLS
# Already have FLS data
# Crawling data for stock: FLR
# Already have FLR data
# Crawling data for stock: FMC
# Already have FMC data
# Crawling data for stock: FL
# Already have FL data
# Crawling data for stock: F
# Already have F data
# Crawling data for stock: FTNT
# Already have FTNT data
# Crawling data for stock: FTV
# Already have FTV data
# Crawling data for stock: FBHS
# Already have FBHS data
# Crawling data for stock: BEN
# Already have BEN data
# Crawling data for stock: FCX
# Already have FCX data
# Crawling data for stock: GPS
# Already have GPS data
# Crawling data for stock: GRMN
# Already have GRMN data
# Crawling data for stock: IT
# Already have IT data
# Crawling data for stock: GD
# Already have GD data
# Crawling data for stock: GE
# Already have GE data
# Crawling data for stock: GIS
# Already have GIS data
# Crawling data for stock: GM
# Already have GM data
# Crawling data for stock: GPC
# Already have GPC data
# Crawling data for stock: GILD
# Already have GILD data
# Crawling data for stock: GPN
# Already have GPN data
# Crawling data for stock: GS
# Already have GS data
# Crawling data for stock: GT
# Already have GT data
# Crawling data for stock: GWW
# Already have GWW data
# Crawling data for stock: HAL
# Already have HAL data
# Crawling data for stock: HBI
# Already have HBI data
# Crawling data for stock: HOG
# Already have HOG data
# Crawling data for stock: HRS
# Already have HRS data
# Crawling data for stock: HIG
# Already have HIG data
# Crawling data for stock: HAS
# Already have HAS data
# Crawling data for stock: HCA
# Already have HCA data
# Crawling data for stock: HCP
# Already have HCP data
# Crawling data for stock: HP
# Already have HP data
# Crawling data for stock: HSIC
# Already have HSIC data
# Crawling data for stock: HSY
# Already have HSY data
# Crawling data for stock: HES
# Already have HES data
# Crawling data for stock: HPE
# Already have HPE data
# Crawling data for stock: HLT
# Already have HLT data
# Crawling data for stock: HFC
# Already have HFC data
# Crawling data for stock: HOLX
# Already have HOLX data
# Crawling data for stock: HD
# Already have HD data
# Crawling data for stock: HON
# Already have HON data
# Crawling data for stock: HRL
# Already have HRL data
# Crawling data for stock: HST
# Already have HST data
# Crawling data for stock: HPQ
# Already have HPQ data
# Crawling data for stock: HUM
# Already have HUM data
# Crawling data for stock: HBAN
# Already have HBAN data
# Crawling data for stock: HII
# Already have HII data
# Crawling data for stock: IDXX
# Already have IDXX data
# Crawling data for stock: INFO
# Already have INFO data
# Crawling data for stock: ITW
# Already have ITW data
# Crawling data for stock: ILMN
# Already have ILMN data
# Crawling data for stock: IR
# Already have IR data
# Crawling data for stock: INTC
# Already have INTC data
# Crawling data for stock: ICE
# Already have ICE data
# Crawling data for stock: IBM
# Already have IBM data
# Crawling data for stock: INCY
# Already have INCY data
# Crawling data for stock: IP
# Already have IP data
# Crawling data for stock: IPG
# Already have IPG data
# Crawling data for stock: IFF
# Already have IFF data
# Crawling data for stock: INTU
# Already have INTU data
# Crawling data for stock: ISRG
# Already have ISRG data
# Crawling data for stock: IVZ
# Already have IVZ data
# Crawling data for stock: IPGP
# Already have IPGP data
# Crawling data for stock: IQV
# Already have IQV data
# Crawling data for stock: IRM
# Already have IRM data
# Crawling data for stock: JEC
# Already have JEC data
# Crawling data for stock: JBHT
# Already have JBHT data
# Crawling data for stock: JEF
# Already have JEF data
# Crawling data for stock: SJM
# Already have SJM data
# Crawling data for stock: JNJ
# Already have JNJ data
# Crawling data for stock: JCI
# Already have JCI data
# Crawling data for stock: JPM
# Already have JPM data
# Crawling data for stock: JNPR
# Already have JNPR data
# Crawling data for stock: KSU
# Already have KSU data
# Crawling data for stock: K
# Already have K data
# Crawling data for stock: KEY
# Already have KEY data
# Crawling data for stock: KMB
# Already have KMB data
# Crawling data for stock: KIM
# Already have KIM data
# Crawling data for stock: KMI
# Already have KMI data
# Crawling data for stock: KLAC
# Already have KLAC data
# Crawling data for stock: KSS
# Already have KSS data
# Crawling data for stock: KHC
# Already have KHC data
# Crawling data for stock: KR
# Already have KR data
# Crawling data for stock: LB
# Already have LB data
# Crawling data for stock: LLL
# Already have LLL data
# Crawling data for stock: LH
# Already have LH data
# Crawling data for stock: LRCX
# Already have LRCX data
# Crawling data for stock: LEG
# Already have LEG data
# Crawling data for stock: LEN
# Already have LEN data
# Crawling data for stock: LLY
# Already have LLY data
# Crawling data for stock: LNC
# Already have LNC data
# Crawling data for stock: LIN
# Already have LIN data
# Crawling data for stock: LKQ
# Already have LKQ data
# Crawling data for stock: LMT
# Already have LMT data
# Crawling data for stock: L
# Already have L data
# Crawling data for stock: LOW
# Already have LOW data
# Crawling data for stock: LYB
# Already have LYB data
# Crawling data for stock: MTB
# Already have MTB data
# Crawling data for stock: MAC
# Already have MAC data
# Crawling data for stock: M
# Already have M data
# Crawling data for stock: MRO
# Already have MRO data
# Crawling data for stock: MPC
# Already have MPC data
# Crawling data for stock: MAR
# Already have MAR data
# Crawling data for stock: MMC
# Already have MMC data
# Crawling data for stock: MLM
# Already have MLM data
# Crawling data for stock: MAS
# Already have MAS data
# Crawling data for stock: MA
# Already have MA data
# Crawling data for stock: MAT
# Already have MAT data
# Crawling data for stock: MKC
# Already have MKC data
# Crawling data for stock: MCD
# Already have MCD data
# Crawling data for stock: MCK
# Already have MCK data
# Crawling data for stock: MDT
# Already have MDT data
# Crawling data for stock: MRK
# Already have MRK data
# Crawling data for stock: MET
# Already have MET data
# Crawling data for stock: MTD
# Already have MTD data
# Crawling data for stock: MGM
# Already have MGM data
# Crawling data for stock: KORS
# Already have KORS data
# Crawling data for stock: MCHP
# Already have MCHP data
# Crawling data for stock: MU
# Already have MU data
# Crawling data for stock: MSFT
# Already have MSFT data
# Crawling data for stock: MAA
# Already have MAA data
# Crawling data for stock: MHK
# Already have MHK data
# Crawling data for stock: TAP
# Already have TAP data
# Crawling data for stock: MDLZ
# Already have MDLZ data
# Crawling data for stock: MNST
# Already have MNST data
# Crawling data for stock: MCO
# Already have MCO data
# Crawling data for stock: MS
# Already have MS data
# Crawling data for stock: MOS
# Already have MOS data
# Crawling data for stock: MSI
# Already have MSI data
# Crawling data for stock: MSCI
# Already have MSCI data
# Crawling data for stock: MYL
# Already have MYL data
# Crawling data for stock: NDAQ
# Already have NDAQ data
# Crawling data for stock: NOV
# Already have NOV data
# Crawling data for stock: NKTR
# Already have NKTR data
# Crawling data for stock: NTAP
# Already have NTAP data
# Crawling data for stock: NFLX
# Already have NFLX data
# Crawling data for stock: NWL
# Already have NWL data
# Crawling data for stock: NFX
# Already have NFX data
# Crawling data for stock: NEM
# Already have NEM data
# Crawling data for stock: NWSA
# Already have NWSA data
# Crawling data for stock: NWS
# Already have NWS data
# Crawling data for stock: NEE
# Already have NEE data
# Crawling data for stock: NLSN
# Already have NLSN data
# Crawling data for stock: NKE
# Already have NKE data
# Crawling data for stock: NI
# Already have NI data
# Crawling data for stock: NBL
# Already have NBL data
# Crawling data for stock: JWN
# Already have JWN data
# Crawling data for stock: NSC
# Already have NSC data
# Crawling data for stock: NTRS
# Already have NTRS data
# Crawling data for stock: NOC
# Already have NOC data
# Crawling data for stock: NCLH
# Already have NCLH data
# Crawling data for stock: NRG
# Already have NRG data
# Crawling data for stock: NUE
# Already have NUE data
# Crawling data for stock: NVDA
# Already have NVDA data
# Crawling data for stock: ORLY
# Already have ORLY data
# Crawling data for stock: OXY
# Already have OXY data
# Crawling data for stock: OMC
# Already have OMC data
# Crawling data for stock: OKE
# Already have OKE data
# Crawling data for stock: ORCL
# Already have ORCL data
# Crawling data for stock: PCAR
# Already have PCAR data
# Crawling data for stock: PKG
# Already have PKG data
# Crawling data for stock: PH
# Already have PH data
# Crawling data for stock: PAYX
# Already have PAYX data
# Crawling data for stock: PYPL
# Already have PYPL data
# Crawling data for stock: PNR
# Already have PNR data
# Crawling data for stock: PBCT
# Already have PBCT data
# Crawling data for stock: PEP
# Already have PEP data
# Crawling data for stock: PKI
# Already have PKI data
# Crawling data for stock: PRGO
# Already have PRGO data
# Crawling data for stock: PFE
# Already have PFE data
# Crawling data for stock: PCG
# Already have PCG data
# Crawling data for stock: PM
# Already have PM data
# Crawling data for stock: PSX
# Already have PSX data
# Crawling data for stock: PNW
# Already have PNW data
# Crawling data for stock: PXD
# Already have PXD data
# Crawling data for stock: PNC
# Already have PNC data
# Crawling data for stock: RL
# Already have RL data
# Crawling data for stock: PPG
# Already have PPG data
# Crawling data for stock: PPL
# Already have PPL data
# Crawling data for stock: PFG
# Already have PFG data
# Crawling data for stock: PG
# Already have PG data
# Crawling data for stock: PGR
# Already have PGR data
# Crawling data for stock: PLD
# Already have PLD data
# Crawling data for stock: PRU
# Already have PRU data
# Crawling data for stock: PEG
# Already have PEG data
# Crawling data for stock: PSA
# Already have PSA data
# Crawling data for stock: PHM
# Already have PHM data
# Crawling data for stock: PVH
# Already have PVH data
# Crawling data for stock: QRVO
# Already have QRVO data
# Crawling data for stock: PWR
# Already have PWR data
# Crawling data for stock: QCOM
# Already have QCOM data
# Crawling data for stock: DGX
# Already have DGX data
# Crawling data for stock: RJF
# Already have RJF data
# Crawling data for stock: RTN
# Already have RTN data
# Crawling data for stock: O
# Already have O data
# Crawling data for stock: RHT
# Already have RHT data
# Crawling data for stock: REG
# Already have REG data
# Crawling data for stock: REGN
# Already have REGN data
# Crawling data for stock: RF
# Already have RF data
# Crawling data for stock: RSG
# Already have RSG data
# Crawling data for stock: RMD
# Already have RMD data
# Crawling data for stock: RHI
# Already have RHI data
# Crawling data for stock: ROK
# Already have ROK data
# Crawling data for stock: COL
# Done
# Crawling data for stock: ROL
# Done
# Crawling data for stock: ROP
# Done
# Crawling data for stock: ROST
# Done
# Crawling data for stock: RCL
# Done
# Crawling data for stock: CRM
# Pause to restart
# Done
# Crawling data for stock: SBAC
# Done
# Crawling data for stock: SCG
# Done
# Crawling data for stock: SLB
# Done
# Crawling data for stock: STX
# Done
# Crawling data for stock: SEE
# Pause to restart
# Done
# Crawling data for stock: SRE
# Done
# Crawling data for stock: SHW
# Done
# Crawling data for stock: SPG
# Done
# Crawling data for stock: SWKS
# Done
# Crawling data for stock: SLG
# Pause to restart
# Done
# Crawling data for stock: SNA
# Done
# Crawling data for stock: SO
# Pause to restart
# Done
# Crawling data for stock: LUV
# Done
# Crawling data for stock: SPGI
# Done
# Crawling data for stock: SWK
# Done
# Crawling data for stock: SBUX
# Done
# Crawling data for stock: STT
# Done
# Crawling data for stock: SRCL
# Done
# Crawling data for stock: SYK
# Done
# Crawling data for stock: STI
# Done
# Crawling data for stock: SIVB
# Pause to restart
# Done
# Crawling data for stock: SYMC
# Done
# Crawling data for stock: SYF
# Done
# Crawling data for stock: SNPS
# Done
# Crawling data for stock: SYY
# Done
# Crawling data for stock: TROW
# Done
# Crawling data for stock: TTWO
# Done
# Crawling data for stock: TPR
# Done
# Crawling data for stock: TGT
# Pause to restart
# Done
# Crawling data for stock: TEL
# Pause to restart
# Done
# Crawling data for stock: FTI
# Done
# Crawling data for stock: TXN
# Done
# Crawling data for stock: TXT
# Pause to restart
# Done
# Crawling data for stock: TMO
# Done
# Crawling data for stock: TIF
# Done
# Crawling data for stock: TWTR
# Done
# Crawling data for stock: TJX
# Done
# Crawling data for stock: TMK
# Done
# Crawling data for stock: TSS
# Done
# Crawling data for stock: TSCO
# Done
# Crawling data for stock: TDG
# Done
# Crawling data for stock: TRV
# Done
# Crawling data for stock: TRIP
# Pause to restart
# Done
# Crawling data for stock: FOXA
# Done
# Crawling data for stock: FOX
# Pause to restart
# Done
# Crawling data for stock: TSN
# Pause to restart
# Done
# Crawling data for stock: UDR
# Pause to restart
# Done
# Crawling data for stock: ULTA
# Done
# Crawling data for stock: USB
# Done
# Crawling data for stock: UAA
# Done
# Crawling data for stock: UA
# Done
# Crawling data for stock: UNP
# Done
# Crawling data for stock: UAL
# Done
# Crawling data for stock: UNH
# Done
# Crawling data for stock: UPS
# Done
# Crawling data for stock: URI
# Done
# Crawling data for stock: UTX
# Done
# Crawling data for stock: UHS
# Done
# Crawling data for stock: UNM
# Done
# Crawling data for stock: VFC
# Done
# Crawling data for stock: VLO
# Done
# Crawling data for stock: VAR
# Done
# Crawling data for stock: VTR
# Done
# Crawling data for stock: VRSN
# Done
# Crawling data for stock: VRSK
# Done
# Crawling data for stock: VZ
# Pause to restart
# Done
# Crawling data for stock: VRTX
# Done
# Crawling data for stock: VIAB
# Done
# Crawling data for stock: V
# Done
# Crawling data for stock: VNO
# Done
# Crawling data for stock: VMC
# Done
# Crawling data for stock: WMT
# Done
# Crawling data for stock: WBA
# Done
# Crawling data for stock: DIS
# Done
# Crawling data for stock: WM
# Done
# Crawling data for stock: WAT
# Done
# Crawling data for stock: WEC
# Done
# Crawling data for stock: WCG
# Done
# Crawling data for stock: WFC
# Done
# Crawling data for stock: WELL
# Pause to restart
# Done
# Crawling data for stock: WDC
# Done
# Crawling data for stock: WU
# Pause to restart
# Done
# Crawling data for stock: WRK
# Done
# Crawling data for stock: WY
# Pause to restart
# Done
# Crawling data for stock: WHR
# Done
# Crawling data for stock: WMB
# Done
# Crawling data for stock: WLTW
# Done
# Crawling data for stock: WYNN
# Done
# Crawling data for stock: XEL
# Done
# Crawling data for stock: XRX
# Done
# Crawling data for stock: XLNX
# Done
# Crawling data for stock: XYL
# Done
# Crawling data for stock: YUM
# Done
# Crawling data for stock: ZBH
# Done
# Crawling data for stock: ZION
# Done
# Crawling data for stock: ZTS
# Pause to restart
# Done

# %%
def compile_sp500_df():
    #check if tickers are already load in memory
    global tickers
    if len(tickers) != 505:
        with open('sp500.pickle', 'rb') as file:
            tickers = pickle.load(file)
            
    sp500_df = pd.DataFrame()
    for count,ticker in enumerate(tickers):
        df = pd.read_csv('stock_dfs/{}.csv'.format(ticker))
        df.set_index('Date', inplace=True)
        
        #rename adjClose column to the stock ticker
        df.rename(columns = {'Adj Close' : ticker}, inplace=True)
        df.drop(['Open','High','Low','Close','Volume'], axis=1, inplace=True)
        
        #joining all df for tickers
        if sp500_df.empty:
            sp500_df = df
        else:
            sp500_df = sp500_df.join(df, how='outer')
        
        if count % 10 == 0:
            print(count, ticker)
            
    print(sp500_df.tail())
    sp500_df.to_csv('sp500_joined_closes_2000.csv')
        
compile_sp500_df()
# Out:
# 0 MMM
# 10 AET
# 20 ALGN
# 30 AEE
# 40 AMGN
# 50 AAPL
# 60 ADP
# 70 BDX
# 80 BSX
# 90 CPB
# 100 CNC
# 110 CHD
# 120 CME
# 130 ED
# 140 CVS
# 150 DFS
# 160 DRE
# 170 EA
# 180 EVRG
# 190 FB
# 200 FLS
# 210 GPS
# 220 GS
# 230 HCP
# 240 HON
# 250 ILMN
# 260 ISRG
# 270 JCI
# 280 KSS
# 290 LNC
# 300 MRO
# 310 MCK
# 320 MAA
# 330 MYL
# 340 NWS
# 350 NCLH
# 360 PKG
# 370 PCG
# 380 PG
# 390 QCOM
# 400 RMD
# 410 SCG
# 420 SO
# 430 SYMC
# 440 TXN
# 450 TRV
# 460 UNP
# 470 VAR
# 480 WMT
# 490 WU
# 500 XYL
#                    MMM        ABT       ABBV        ABMD         ACN  \
# Date
# 2018-10-25  184.990005  67.669998  81.730003  333.119995  156.919998
# 2018-10-26  184.949997  66.989998  80.790001  330.350006  154.449997
# 2018-10-29  185.789993  67.309998  81.360001  320.029999  152.740005
# 2018-10-30  189.809998  68.000000  81.589996  331.220001  154.619995
# 2018-10-31  190.259995  68.940002  77.849998  341.200012  157.619995
#
#                  ATVI        ADBE        AMD         AAP        AES  \
# Date
# 2018-10-25  70.320000  252.919998  19.270000  163.169998  14.580965
# 2018-10-26  68.839996  245.800003  17.629999  164.550003  14.422368
# 2018-10-29  65.220001  239.750000  16.850000  164.869995  14.392632
# 2018-10-30  67.480003  238.410004  17.200001  164.970001  14.690000
# 2018-10-31  69.050003  245.759995  18.209999  159.759995  14.580000
#
#               ...            WLTW        WYNN        XEL        XRX  \
# Date          ...
# 2018-10-25    ...      138.110001  103.220001  49.430000  27.740000
# 2018-10-26    ...      139.009995  100.510002  48.509998  27.389999
# 2018-10-29    ...      140.360001   94.180000  49.410000  27.459999
# 2018-10-30    ...      141.179993   97.599998  49.689999  28.209999
# 2018-10-31    ...      143.160004  100.599998  49.009998  27.870001
#
#                  XLNX        XYL        YUM         ZBH       ZION        ZTS
# Date
# 2018-10-25  79.400002  66.634453  86.919998  122.150002  47.150002  90.470001
# 2018-10-26  78.779999  66.305519  85.779999  115.129997  46.560001  88.849998
# 2018-10-29  78.349998  65.488159  85.470001  115.290001  47.040001  89.650002
# 2018-10-30  82.050003  64.919998  86.430000  114.580002  46.900002  90.180000
# 2018-10-31  85.370003  65.580002  90.410004  113.589996  47.049999  90.150002
#
# [5 rows x 505 columns]

# %%
def produce_correlation_table():
    sp500_df = pd.read_csv('sp500_joined_closes_2000.csv')
    df_corr = sp500_df.corr()
    print(df_corr.head())

produce_correlation_table()
# Out:
#            MMM       ABT      ABBV      ABMD       ACN      ATVI      ADBE  \
# MMM   1.000000  0.961362  0.926822  0.796200  0.978007  0.943134  0.901792
# ABT   0.961362  1.000000  0.942159  0.811709  0.977788  0.923420  0.899484
# ABBV  0.926822  0.942159  1.000000  0.887824  0.935270  0.921738  0.933348
# ABMD  0.796200  0.811709  0.887824  1.000000  0.859935  0.916028  0.964623
# ACN   0.978007  0.977788  0.935270  0.859935  1.000000  0.955937  0.928759
#
#            AMD       AAP       AES    ...         WLTW      WYNN       XEL  \
# MMM  -0.264304  0.855982 -0.244268    ...     0.938586  0.723044  0.967800
# ABT  -0.321922  0.877545 -0.213723    ...     0.896903  0.777325  0.960851
# ABBV  0.736115  0.153830  0.259509    ...     0.932296  0.251202  0.849207
# ABMD  0.056239  0.597378 -0.032265    ...     0.770147  0.500707  0.793946
# ACN  -0.153672  0.862519  0.071601    ...     0.922069  0.728106  0.981536
#
#            XRX      XLNX       XYL       YUM       ZBH      ZION       ZTS
# MMM   0.004288  0.774778  0.933670  0.959729  0.895331 -0.063814  0.899775
# ABT  -0.064060  0.765276  0.915770  0.978486  0.837808 -0.166741  0.952858
# ABBV  0.333712  0.894779  0.944445  0.934911  0.722988  0.894649  0.944503
# ABMD  0.014318  0.777944  0.914623  0.765009  0.669431  0.130446  0.958686
# ACN   0.009202  0.952465  0.966692  0.977819  0.844529 -0.118614  0.970620
#
# [5 rows x 505 columns]
